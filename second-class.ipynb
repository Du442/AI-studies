# %% [markdown]
# # connecting IA in my notebook

# %%
from dotenv import load_dotenv
import os

load_dotenv()

GOOGLE_API_KEY = os.getenv('GEMINI_API_KEY')

# %%
from google import genai

client = genai.Client(api_key=GOOGLE_API_KEY)
modelo = 'gemini-2.5-flash'

# %%
# response = client.models.generate_content(
#     model='gemini-2.5-flash',
#     contents='Como a IA funciona?'
# )
# print(response.text)

# %%
# interaction = client.interactions.create(
#     model='gemini-2.5-flash',
#     # input='Como a IA funciona?',
#     generation_config={
#         'thinking_level': 'low'
#     }
# )
# print(interaction.output_text)

# %% [markdown]
# # loop structures

# %%
n = 1
asc = '*'

while n != 10:
    print(asc)
    n += 1
# Out:
# *
# *
# *
# *
# *
# *
# *
# *
# *

# %%
chat = client.chats.create(model=modelo)

# %%
resposta = chat.send_message('O que é a inteligencia artificial?')

# %%
# print(resposta.text)

# %%
# resposta = chat.send_message('Quando foi lançado o chatgpt?')
# print(resposta.text)

# %%
# chat.get_history()

# %%
def exibir_opcoes():
    print('''
Digite a opção escolhida
1 - Mandar pergunta
2 - Visualizar histórico
3 - Sair
''')

# while True:
#     exibir_opcoes()
#     opcao_escolhida = int(input('\nDigite a opção escolhida: '))
#     if opcao_escolhida == 1:
#         prompt = input('Digite sua mensagem: ')
#         resposta = chat.send_message(prompt)
#         print(resposta.text)
#     elif opcao_escolhida == 2:
#         print(chat.get_history())
#     elif opcao_escolhida == 3:
#         break
#     else:
#         print('Digite uma opção válida.\n')

# %% [markdown]
# # data structures

# %% [markdown]
# lists

# %%
nomes_completos = [
    "Ana Silva",
    "Lucas Oliveira",
    "Mariana Santos",
    "Pedro Almeida",
    "Beatriz Costa"
]

# %%
nomes_completos[1]
# Out:
# 'Lucas Oliveira'

# %%
lista_de_medias = [8.9, 7.5, 9.2, 6.8, 9.5]

# %%
lista_nova = []

for i in lista_de_medias:
    if i >= 9.0:
        i = 10.0
        lista_nova.append(i)
    else:
        i += 1
        lista_nova.append(i)

print(lista_nova)
# Out:
# [9.9, 8.5, 10.0, 7.8, 10.0]

# %%
len(lista_de_medias)
# Out:
# 5

# %%
dict_nome_media = {
    'Maria Silva': 8.9,
    'João Santos': 7.5,
    'Ana Oliveira': 4.2,
    'Pedro Costa': 1.4,
    'Juliana Pereira': 9.5
}

# %%
dict_nome_media['Maria Silva']
# Out:
# 8.9

# %%
dict_nome_media
# Out:
# {'Maria Silva': 8.9,
#  'João Santos': 7.5,
#  'Ana Oliveira': 4.2,
#  'Pedro Costa': 1.4,
#  'Juliana Pereira': 9.5}

# %%
dict_nome_media.keys()
# Out:
# dict_keys(['Maria Silva', 'João Santos', 'Ana Oliveira', 'Pedro Costa', 'Juliana Pereira'])

# %%
list_comp = [{'nome': x, 'medias': y} for x, y in zip(nomes_completos, lista_de_medias)]

# %%
list_comp
# Out:
# [{'nome': 'Ana Silva', 'medias': 8.9},
#  {'nome': 'Lucas Oliveira', 'medias': 7.5},
#  {'nome': 'Mariana Santos', 'medias': 9.2},
#  {'nome': 'Pedro Almeida', 'medias': 6.8},
#  {'nome': 'Beatriz Costa', 'medias': 9.5}]

# %%
for i in range(len(list_comp)):
    print(list_comp[i])
# Out:
# {'nome': 'Ana Silva', 'medias': 8.9}
# {'nome': 'Lucas Oliveira', 'medias': 7.5}
# {'nome': 'Mariana Santos', 'medias': 9.2}
# {'nome': 'Pedro Almeida', 'medias': 6.8}
# {'nome': 'Beatriz Costa', 'medias': 9.5}

# %%
nome = input('Digite um nome: ')
idade = int(input("Digite sua idade: "))
altura = float(input('digite sua altura: '))

# %%
pessoa = {
    'Nome':nome,
    'idade':idade,
    'altura':altura
}

# %%
for chave in pessoa:
    print(chave)
# Out:
# Nome
# idade
# altura

# %%
for chave, valor in pessoa.items():
    print(f'{chave}: {valor}')
# Out:
# Nome: eduardo
# idade: 10
# altura: 1.675

# %%
nome1 = 'mariana SILVa dos santos'
nome2 ='JoÃO ferreira de melo'
nome3 = '  CARLOS eduardo pereira nunes'
nome4 = '   ana    PAULA costa'
nome5 = 'rafael GOMes da silVA'

# %%
def escreve_texto_corretamente(*nomes):
    for nome in nomes:
        nome_formatado = nome.lower().strip().replace('    ', ' ')
        print(nome_formatado)

# %%
def escreve_texto_corretamente2(*nomes):
    for nome in nomes:
        lista_nomes = nome.lower().split()
        nome_final = ' '.join(lista_nomes)
        return nome_final

# %%
escreve_texto_corretamente2(nome1, nome2, nome3, nome4, nome5)
# Out:
# 'mariana silva dos santos'

# %%
import random

def aloca_alunos(nome_aluno: str, lista: list):
    numero_aleatorio = random.choice(lista)
    dict_aluno = {'nome': nome_aluno, 'sala': numero_aleatorio}
    return dict_aluno
        
salas_de_aula = ['Sala 1', 'Sala 2', 'Sala 3']

aloca_alunos('Jorge', salas_de_aula)
# Out:
# {'nome': 'Jorge', 'sala': 'Sala 1'}

# %% [markdown]
# ### Challenge

# %%
corpos_emails = [
    # 1. Boas-vindas
    "Olá!\n\nSeja muito bem-vindo(a) à nossa plataforma! Estamos muito felizes em ter você conosco. Se precisar de qualquer suporte para começar, basta responder a este e-mail.\n\nAtenciosamente,\nEquipe de Atendimento",
    
    # 2. Confirmação de Reunião
    "Olá,\n\nConfirmando nossa reunião agendada para amanhã, às 14h. O link para a sala virtual segue abaixo. Caso precise reagendar, por favor nos avise com antecedência.\n\nAtenciosamente,\nEquipe de Suporte",
    
    # 3. Envio de Orçamento
    "Prezado(a),\n\nConforme conversamos, segue em anexo a proposta comercial solicitada. O orçamento é válido por 15 dias corridos.\n\nFicamos à disposição para esclarecer qualquer dúvida.\n\nAtenciosamente,\nDepartamento Comercial",
    
    # 4. Lembrete de Pagamento / Fatura
    "Olá,\n\nLembramos que a sua fatura com vencimento para os próximos dias já está disponível. Você pode acessar o boleto em anexo para efetuar o pagamento.\n\nQualquer dúvida, estamos à disposição.\n\nSetor Financeiro",
    
]

# %%
client = genai.Client()

def resumir_emails(lista: list):
    for i in range(len(lista)):
        resposta_individual = client.interactions.create(
            model='gemini-2.5-flash',
            input=f'Resuma o o seguinte email para que eu saiba do que ele se trata: {lista[i]} '
        )
        print(f'{i+1}. {resposta_individual.output_text}')

def resumir_emails_curso(lista_de_emails):
    lista_de_resumos = []

    for numero, email in enumerate(lista_de_emails):
        resposta = client.interactions.create(
            model='gemini-2.5-flash',
            input=f'''Vou te mandar o corpo de um email. Quero que você o resuma em apenas 1 linha,
            passando o intuito daquele email. Segue o email:{email}'''
        )
        print(f'E-mail: {numero + 1}: {resposta.output_text}')
        lista_de_resumos.append(f'E-mail: {numero}: {resposta.output_text}')
        print('-' * 50)

    return lista_de_resumos
# resumir_emails(corpos_emails)

# %% [markdown]
# # GROQ

# %%
from groq import Groq

GROQ_API_KEY = os.getenv('GROQ_API_KEY')

# %%
client = Groq(api_key=GROQ_API_KEY)

resposta = client.chat.completions.create(
    messages=[
        {
            'role': 'user',
            'content': 'Explique a importante da velocidade dos modelos de linguagem'
        }
    ],
    model='llama-3.3-70b-versatile'
)

print(resposta.choices[0].message.content)
# Out:
# A velocidade dos modelos de linguagem é um aspecto fundamental na era digital, onde a rapidez e a eficiência são essenciais para diversas aplicações. Aqui estão algumas razões pelas quais a velocidade dos modelos de linguagem é importante:
#
# 1. **Resposta Rápida**: Em muitas aplicações, como chatbots, assistentes virtuais e interfaces de linguagem natural, a velocidade de resposta é crucial. Os usuários esperam respostas rápidas e precisas, e um modelo de linguagem lento pode frustrar o usuário e afetar a experiência geral.
# 2. **Eficiência de Processamento**: A velocidade dos modelos de linguagem também afeta a eficiência de processamento. Modelos mais rápidos podem processar grandes volumes de texto e realizar tarefas complexas, como tradução, resumo e análise de sentimento, em um curto período de tempo.
# 3. **Escalabilidade**: A velocidade dos modelos de linguagem é essencial para aplicações em larga escala, como processamento de grandes conjuntos de dados, análise de texto e mineração de dados. Modelos mais rápidos podem lidar com volumes maiores de dados e realizar tarefas mais complexas.
# 4. **Interação em Tempo Real**: A velocidade dos modelos de linguagem é fundamental para aplicações que exigem interação em tempo real, como conversas, jogos e simulações. Modelos mais rápidos podem responder rapidamente a entradas do usuário e fornecer uma experiência mais imersiva.
# 5. **Melhoria da Experiência do Usuário**: A velocidade dos modelos de linguagem pode melhorar significativamente a experiência do usuário. Modelos mais rápidos podem fornecer respostas mais rápidas e precisas, o que pode aumentar a satisfação do usuário e reduzir a taxa de abandono.
# 6. **Redução do Custo**: A velocidade dos modelos de linguagem também pode reduzir o custo de processamento e armazenamento. Modelos mais rápidos podem processar dados mais rapidamente, o que pode reduzir a necessidade de recursos computacionais e armazenamento.
# 7. **Aumento da Produtividade**: A velocidade dos modelos de linguagem pode aumentar a produtividade em diversas áreas, como escritório, educação e pesquisa. Modelos mais rápidos podem automatizar tarefas rotineiras e liberar tempo para tarefas mais complexas e criativas.
#
# Para alcançar velocidades mais rápidas, os modelos de linguagem podem ser otimizados de várias maneiras, incluindo:
#
# * **Aumento da paralelização**: Dividir o processamento em múltiplos processos ou threads para aproveitar recursos computacionais adicionais.
# * **Otimização do algoritmo**: Melhorar o algoritmo de processamento para reduzir o tempo de execução e melhorar a eficiência.
# * **Uso de hardware especializado**: Utilizar hardware especializado, como GPUs ou TPUs, para acelerar o processamento de modelos de linguagem.
# * **Redução do tamanho do modelo**: Reduzir o tamanho do modelo para diminuir o tempo de processamento e melhorar a eficiência.
# * **Uso de técnicas de pré-processamento**: Utilizar técnicas de pré-processamento, como tokenização e normalização, para reduzir o tempo de processamento.
#
# Em resumo, a velocidade dos modelos de linguagem é fundamental para aplicações que exigem resposta rápida, eficiência de processamento, escalabilidade, interação em tempo real e melhoria da experiência do usuário. A otimização da velocidade dos modelos de linguagem pode ser alcançada por meio de várias técnicas, incluindo aumento da paralelização, otimização do algoritmo, uso de hardware especializado, redução do tamanho do modelo e uso de técnicas de pré-processamento.

# %% [markdown]
# ## Lendo e escrevendo arquivos usando Python

# %%
lista_de_resumos = resumir_emails_curso(corpos_emails)

with open(file='lista_de_resumos.txt', mode='w', encoding='utf-8') as file:
    for elemento in lista_de_resumos:
        file.write(elemento + '\n')
# Out:
# E-mail: 1: O e-mail dá as boas-vindas a um novo usuário na plataforma e oferece suporte inicial.
# --------------------------------------------------
# E-mail: 2: Confirmação da reunião agendada para amanhã, com link e opção de reagendamento.
# --------------------------------------------------
# E-mail: 3: Envio da proposta comercial solicitada, que segue anexa com validade de 15 dias e disponibilidade para esclarecer dúvidas.
# --------------------------------------------------
# E-mail: 4: Sua fatura para pagamento está disponível e anexa.
# --------------------------------------------------
