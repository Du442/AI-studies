# %% [markdown]
# # connecting IA in my notebook

# %%
from dotenv import load_dotenv
import os

load_dotenv()

GOOGLE_API_KEY = os.getenv('GEMINI_API_KEY')

# %%
from google import genai

client = genai.Client(api_key=GOOGLE_API_KEY)
modelo = 'gemini-2.5-flash'

# %%
# response = client.models.generate_content(
#     model='gemini-2.5-flash',
#     contents='Como a IA funciona?'
# )
# print(response.text)

# %%
# interaction = client.interactions.create(
#     model='gemini-2.5-flash',
#     # input='Como a IA funciona?',
#     generation_config={
#         'thinking_level': 'low'
#     }
# )
# print(interaction.output_text)

# %% [markdown]
# # loop structures

# %%
n = 1
asc = '*'

while n != 10:
    print(asc)
    n += 1
# Out:
# *
# *
# *
# *
# *
# *
# *
# *
# *

# %%
chat = client.chats.create(model=modelo)

# %%
resposta = chat.send_message('O que é a inteligencia artificial?')

# %%
# print(resposta.text)

# %%
# resposta = chat.send_message('Quando foi lançado o chatgpt?')
# print(resposta.text)

# %%
# chat.get_history()

# %%
def exibir_opcoes():
    print('''
Digite a opção escolhida
1 - Mandar pergunta
2 - Visualizar histórico
3 - Sair
''')

# while True:
#     exibir_opcoes()
#     opcao_escolhida = int(input('\nDigite a opção escolhida: '))
#     if opcao_escolhida == 1:
#         prompt = input('Digite sua mensagem: ')
#         resposta = chat.send_message(prompt)
#         print(resposta.text)
#     elif opcao_escolhida == 2:
#         print(chat.get_history())
#     elif opcao_escolhida == 3:
#         break
#     else:
#         print('Digite uma opção válida.\n')

# %% [markdown]
# # data structures

# %% [markdown]
# lists

# %%
nomes_completos = [
    "Ana Silva",
    "Lucas Oliveira",
    "Mariana Santos",
    "Pedro Almeida",
    "Beatriz Costa"
]

# %%
nomes_completos[1]
# Out:
# 'Lucas Oliveira'

# %%
lista_de_medias = [8.9, 7.5, 9.2, 6.8, 9.5]

# %%
lista_nova = []

for i in lista_de_medias:
    if i >= 9.0:
        i = 10.0
        lista_nova.append(i)
    else:
        i += 1
        lista_nova.append(i)

print(lista_nova)
# Out:
# [9.9, 8.5, 10.0, 7.8, 10.0]

# %%
len(lista_de_medias)
# Out:
# 5

# %%
dict_nome_media = {
    'Maria Silva': 8.9,
    'João Santos': 7.5,
    'Ana Oliveira': 4.2,
    'Pedro Costa': 1.4,
    'Juliana Pereira': 9.5
}

# %%
dict_nome_media['Maria Silva']
# Out:
# 8.9

# %%
dict_nome_media
# Out:
# {'Maria Silva': 8.9,
#  'João Santos': 7.5,
#  'Ana Oliveira': 4.2,
#  'Pedro Costa': 1.4,
#  'Juliana Pereira': 9.5}

# %%
dict_nome_media.keys()
# Out:
# dict_keys(['Maria Silva', 'João Santos', 'Ana Oliveira', 'Pedro Costa', 'Juliana Pereira'])

# %%
list_comp = [{'nome': x, 'medias': y} for x, y in zip(nomes_completos, lista_de_medias)]

# %%
list_comp
# Out:
# [{'nome': 'Ana Silva', 'medias': 8.9},
#  {'nome': 'Lucas Oliveira', 'medias': 7.5},
#  {'nome': 'Mariana Santos', 'medias': 9.2},
#  {'nome': 'Pedro Almeida', 'medias': 6.8},
#  {'nome': 'Beatriz Costa', 'medias': 9.5}]

# %%
for i in range(len(list_comp)):
    print(list_comp[i])
# Out:
# {'nome': 'Ana Silva', 'medias': 8.9}
# {'nome': 'Lucas Oliveira', 'medias': 7.5}
# {'nome': 'Mariana Santos', 'medias': 9.2}
# {'nome': 'Pedro Almeida', 'medias': 6.8}
# {'nome': 'Beatriz Costa', 'medias': 9.5}

# %%
nome = input('Digite um nome: ')
idade = int(input("Digite sua idade: "))
altura = float(input('digite sua altura: '))

# %%
pessoa = {
    'Nome':nome,
    'idade':idade,
    'altura':altura
}

# %%
for chave in pessoa:
    print(chave)
# Out:
# Nome
# idade
# altura

# %%
for chave, valor in pessoa.items():
    print(f'{chave}: {valor}')
# Out:
# Nome: e
# idade: 10
# altura: 1.5

# %%
nome1 = 'mariana SILVa dos santos'
nome2 ='JoÃO ferreira de melo'
nome3 = '  CARLOS eduardo pereira nunes'
nome4 = '   ana    PAULA costa'
nome5 = 'rafael GOMes da silVA'

# %%
def escreve_texto_corretamente(*nomes):
    for nome in nomes:
        nome_formatado = nome.lower().strip().replace('    ', ' ')
        print(nome_formatado)

# %%
def escreve_texto_corretamente2(*nomes):
    for nome in nomes:
        lista_nomes = nome.lower().split()
        nome_final = ' '.join(lista_nomes)
        return nome_final

# %%
escreve_texto_corretamente2(nome1, nome2, nome3, nome4, nome5)
# Out:
# 'mariana silva dos santos'

# %%
import random

def aloca_alunos(nome_aluno: str, lista: list):
    numero_aleatorio = random.choice(lista)
    dict_aluno = {'nome': nome_aluno, 'sala': numero_aleatorio}
    return dict_aluno
        
salas_de_aula = ['Sala 1', 'Sala 2', 'Sala 3']

aloca_alunos('Jorge', salas_de_aula)
# Out:
# {'nome': 'Jorge', 'sala': 'Sala 2'}

# %% [markdown]
# ### Challenge

# %%
corpos_emails = [
    # 1. Boas-vindas
    "Olá!\n\nSeja muito bem-vindo(a) à nossa plataforma! Estamos muito felizes em ter você conosco. Se precisar de qualquer suporte para começar, basta responder a este e-mail.\n\nAtenciosamente,\nEquipe de Atendimento",
    
    # 2. Confirmação de Reunião
    "Olá,\n\nConfirmando nossa reunião agendada para amanhã, às 14h. O link para a sala virtual segue abaixo. Caso precise reagendar, por favor nos avise com antecedência.\n\nAtenciosamente,\nEquipe de Suporte",
    
    # 3. Envio de Orçamento
    "Prezado(a),\n\nConforme conversamos, segue em anexo a proposta comercial solicitada. O orçamento é válido por 15 dias corridos.\n\nFicamos à disposição para esclarecer qualquer dúvida.\n\nAtenciosamente,\nDepartamento Comercial",
    
    # 4. Lembrete de Pagamento / Fatura
    "Olá,\n\nLembramos que a sua fatura com vencimento para os próximos dias já está disponível. Você pode acessar o boleto em anexo para efetuar o pagamento.\n\nQualquer dúvida, estamos à disposição.\n\nSetor Financeiro",
    
    # 5. Agradecimento por Compra
    "Oi!\n\nObrigado por comprar conosco! Seu pedido já está sendo preparado com muito carinho e em breve enviaremos o código de rastreamento por aqui.\n\nTenha um ótimo dia!\nEquipe de Vendas",
    
    # 6. Prospecção Fria (Cold Mail)
    "Olá,\n\nVi o perfil da sua empresa e pensei que você poderia se interessar por nossa solução, que ajuda a otimizar processos operacionais e reduzir custos. Teria 10 minutos nesta semana para uma breve conversa?\n\nAtenciosamente,\nConsultor de Negócios",
    
    # 7. Follow-up de Proposta
    "Olá!\n\nTudo bem? Gostaria de saber se você conseguiu analisar a proposta enviada na semana passada. Podemos marcar uma ligação rápida para alinhar os detalhes finais?\n\nUm abraço,\nEquipe de Atendimento",
    
    # 8. Feedback do Cliente
    "Olá,\n\nSua opinião é extremamente importante para nós! Poderia responder a uma pesquisa rápida (menos de 3 minutos) sobre sua experiência recente com nossos serviços?\n\nAgradecemos desde já!\nEquipe de Qualidade",
    
    # 9. Notificação de Manutenção do Sistema
    "Prezados clientes,\n\nInformamos que nosso sistema passará por uma manutenção programada neste domingo, das 02h às 06h. Durante esse período, o acesso poderá apresentar instabilidade.\n\nAgradecemos a compreensão.\nEquipe de TI",
    
    # 10. Solicitação de Documentos
    "Olá,\n\nPara darmos continuidade ao seu processo de cadastro, solicitamos o envio de uma cópia legível do comprovante de residência e do documento de identidade atualizado.\n\nNo aguardo,\nSetor Cadastral",
    
    # 11. Recuperação de Carrinho Abandonado
    "Oi!\n\nNotamos que você deixou alguns itens no seu carrinho. Não perca a oportunidade de garantir seus produtos com condições especiais e frete promocional.\n\nClique no botão abaixo para finalizar sua compra!\nEquipe de Vendas",
    
    # 12. Convite para Webinar / Evento
    "Olá!\n\nConvidamos você para o nosso próximo webinar sobre inovação e tendências de mercado. O evento acontecerá na próxima quinta-feira, às 19h. As vagas são limitadas!\n\nInscreva-se pelo link abaixo.\nAtenciosamente,\nEquipe de Marketing",
    
    # 13. Mudança nos Termos de Uso
    "Prezado(a) usuário(a),\n\nAtualizamos nossos Termos de Serviço e Política de Privacidade para garantir ainda mais transparência e segurança aos seus dados. Recomendamos a leitura do documento atualizado em nosso site.\n\nAtenciosamente,\nEquipe de Segurança",
    
    # 14. E-mail de Ausência (Out of Office)
    "Olá!\n\nObrigado por entrar em contato. Estou em período de ausência do escritório e com acesso limitado ao e-mail. Para assuntos urgentes, favor contatar o suporte geral da empresa.\n\nAtenciosamente,\nEquipe de Atendimento",
    
    # 15. Agradecimento por Reunião
    "Olá,\n\nMuito obrigado pelo tempo dedicado na nossa reunião de hoje. Foi excelente entender melhor suas necessidades. Conforme combinado, enviaremos o resumo e os próximos passos em breve.\n\nAtenciosamente,\nEquipe Comercial",
    
    # 16. Atualização de Status do Pedido
    "Oi!\n\nBoas notícias: seu pedido acabou de ser faturado e entregue à transportadora! Você pode acompanhar o envio utilizando o código de rastreio em anexo.\n\nAtenciosamente,\nCentral de Entregas",
    
    # 17. Solicitação de Indicação
    "Olá!\n\nFicamos muito felizes em ver você usando nossas soluções. Conhece alguma empresa ou amigo que também poderia se beneficiar? Indique nosso serviço e receba um cupom de desconto na sua próxima mensalidade!\n\nUm abraço,\nEquipe de Relacionamento",
    
    # 18. Alerta de Segurança / Tentativa de Login
    "Aviso de Segurança:\n\nDetectamos um novo acesso à sua conta a partir de um dispositivo não reconhecido. Se foi você, desconsidere esta mensagem. Caso contrário, altere sua senha imediatamente através do painel principal.\n\nEquipe de Segurança",
    
    # 19. Newsletter / Artigo Novo
    "Olá!\n\nAcabamos de publicar um conteúdo inédito no nosso blog com dicas práticas para melhorar a gestão do seu dia a dia. Confira a leitura completa no link abaixo!\n\nBoa leitura,\nEquipe de Conteúdo",
    
    # 20. Encerramento de Contato (Breakup Mail)
    "Olá,\n\nComo não tivemos retorno às mensagens anteriores, assumimos que este projeto não é uma prioridade no momento. Estaremos encerrando as tentativas de contato, mas ficamos à inteira disposição caso queira retomar no futuro.\n\nAtenciosamente,\nEquipe Comercial"
]

# %%
client = genai.Client()

def resumir_emails(lista: list):
    for i in range(len(lista)):
        resposta_individual = client.interactions.create(
            model='gemini-2.5-flash',
            input=f'Resuma o o seguinte email para que eu saiba do que ele se trata: {lista[i]} '
        )
        print(f'{i+1}. {resposta_individual.output_text}')

# resumir_emails(corpos_emails)

# %% [markdown]
# # GROQ

# %%
from groq import Groq

GROQ_API_KEY = os.getenv('GROQ_API_KEY')

# %%
client = Groq()

completion = client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {
            'role': 'system',
            'content': 'Do que é feito o sol?'
        },
    ],
    temperature=1,
    max_completation_tokens=8192,
    top_p=1,
    reasoning_effort='medium',
    stream=True,
    stop=None
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")
